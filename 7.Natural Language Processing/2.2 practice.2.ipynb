# %%
import gensim

# %%
gensim.__version__
# Out:
# '4.0.1'

# %% [markdown]
# # Step 1
# 훈련 데이터 (말뭉치) 준비하기:
# 주어진 데이터로 Word2Vec 모델 학습

# %%
# 데이터 처리를 담당할 클래스
class TextIterator(object):
    def __init__(self, fname):
        self.fname = fname

    def __iter__(self):
        for line in open(self.fname):
            yield line.split()

# %%
# 훈련 데이터 불러오기
filename = './data/newskor.txt'
sentences = TextIterator(filename)

# %% [markdown]
# # Step 2
# Word2Vec 모델 훈련시키기
#
# # Step 3
# 훈련이 끝난 모델을 불러오기

# %%
# hyper-parameters
TRAIN = True # 동작 플래그 (True: 훈련 / False: 불러오기)
SIZE = 300 # 임베딩 벡터의 차원
WINDOW = 5 # context window 주변단어 5개와의 관계
SG = 1 # 1: skip-gram / 그 외: CBOW
MIN_COUNT = 10 # 출현 빈도가 이 값보다 작은 단어는 무시함
WORKERS = 20 # threads

# %%
# 모델을 훈련하거나 불러오는 함수
def train_word2vec(train):
    if train:
        # gensim 4.0.1
        model = gensim.models.Word2Vec(
            vector_size=SIZE, window=WINDOW, sg=SG, 
            min_count=MIN_COUNT, workers=WORKERS
        )
        # vocabulary 생성 (index 생성 -> one-hot vector생성 단계)
        model.build_vocab(sentences) 
        # 훈련 시작
        model.train(sentences, total_examples=model.corpus_count, epochs=5) # total_examples : 문장의 수
        # 모델 저장
        model.save('./save_files/newskor.model')
    else:
        # 저장된 모델 불러오기
        model = gensim.models.Word2Vec.load('./save_files/newskor.model')
    return model

# %%
model = train_word2vec(TRAIN)

# %%
# model.corpus_count
# Out:
# 430720

# %%
print(type(model.wv))
# Out:
# <class 'gensim.models.keyedvectors.KeyedVectors'>

# %%
# show the vocabulary
# print(model.wv.vocab)
print(model.wv.index_to_key)
# Out:
# ['하', '이', '.', '는', '을', 'ㄴ', '다', '의', '에', '를', '은', '어', '있', '고', '으로', '가', '였', 'ㄹ', '되', ',', '에서', '었', ')', '(', '로', '것', '도', '등', '과', '들', '지', '와', '여', '일', '기', '·', 'ㄴ다', '적', '수', '아', '%', '게', '원', '년', '2', '았', '3', '1', '다고', '“', '”', '월', '위하', '대하', '말하', '시장', '면', '업체', '따르', '하고', '않', '만', '까지', '‘', '’', '밝히', '명', '및', '부터', '다가', '미국', '며', '이라고', '4', '개', '대', '나', '오', '대표', '국내', '한국', '5', '다는', '던', '서비스', '습니다', '개발', '계획', '인', '주', '통하', '제품', '없', '또', '화', '정부', '면서', '최근', '한', '으며', '6', '지난해', '중', '그', '사업', '올해', '중국', '보이', '크', '받', '일본', '이번', '10', '보다', '내', '기업', '경우', '보', '대통령', '같', '-', '관련', '기술', '에게', '지만', '때문', '전', '전망', 'LG', '라고', '7', '달러', '현재', '예정', '지나', '어서', 'ㄴ다는', '특히', '이상', '8', '북한', '사', '시스템', '문제', '김', '삼성전자', '겠', '늘', '간', '나서', '관계자', '잇', '9', '아니', '라는', '용', '인터넷', '높', '라', '내년', '솔루션', '위', '데', '회사', '시키', '장비', 'ㅁ', '씨', '업계', '이날', '때', '다면서', '두', '세계', '도록', '예상', '추진', '게임', 'PC', '그러나', '말', '확대', '한편', '수출', '공급', '함께', 'ㄴ다고', '전자', '매출', '구축', '많', '못하', '점', '으나', '20', '규모', '투자', '분야', '이후', 'TV', '서울', 'IT', '가운데', '지역', '경기', '세', '뒤', '시작', 'SK', '사용', '디지털', '시', '자', '기존', '지원', '라면서', '가격', '단말기', '이나', '제공', '정도', '방침', '어야', 'LCD', '발표', '본격', '텔레콤', '알리', '11', '30', '분기', '이르', 'ㅂ니다', '12', '노', '확보', '열리', '가장', '정보', '조사', '대상', '기록', '기대', '출시', '여야', '가능성', '판매', '안', '더', '사장', '가능', '*', '모두', '도입', '이용', '다른', '상황', '기반', '강화', '진출', '수준', '갖', '키', '설명', '필요', '앞', '증가', '포함', '휴대폰', '결과', '∼', '해외', '비하', '기능', '0', '올', '공동', '후', '15', '차', '전략', '일부', '지적', '처음', '분', '방식', '방안', '반도체', '마련', '형', '2000', '주요', '회', '만들', '는데', '주장', '결정', '분석', '생산', '나오', '요', '전체', '국가', '당', '나타나', '통합', '사업자', '가지', '관리', '새롭', '△', '그동안', '삼성', '의원', 'KT', '이라크', '중심', '미', '참여', '경쟁', '우리', '요구', '장관', 'e', '수요', '이미', '제', '산업', 'D', '추가', '프로젝트', '최대', '각각', '칩', '내용', '초', '물론', '다양', '거나', '서버', '나가', '시간', '알', '적용', '전하', '좋', '오르', '성장', '벌이', '상', '약', '50', '16', '실시', '검찰', '박', '콘텐츠', '네트워크', '정책', '마케팅', '뿐', '하지만', '총', '모바일', '평가', '대한', '배', '감독', '하반기', '부문', '13', '25', '사람', '선정', '고객', '처럼', '향후', '계속', '활용', '방송', '들어가', '14', '듣', '열', '장', '이란', '계', '온라인', '경제', '설립', '만큼', '"', '17', '사실', '회장', '대비', '발생', '자체', '차세대', '올리', '상태', '높이', '적극', '인하', '한나라당', '계약', '협력', '성공', '차지', '선보이', '앞서', '21', '어렵', '진행', '떨어지', '유럽', '운영', '18', '개월', '이루', '목표', '달', '집중', '보안', '팀', '상반기', '관심', '=', '번', '지난달', '검토', '작업', '다시', '협상', '100', '우려', '자신', '40', '통신', '소프트웨어', '모든', '하나', '확인', '인치', '아직', '그룹', '더욱', '동안', '지금', '공략', '&', '교수', '직접', '측', '기준', '국민', '구성', '대부분', '곳', '생각', '코리아', '놓', '강조', "'", '24', '반면', '카드', '국회', '총리', '맞', '센터', '건', '실적', '입장', '타', '가량', '기간', '정', '밖에', '보도', '데이터', '19', '유지', '지속', '논의', '프로그램', '대형', '개선', '이달', '방문', '갖추', '체결', '첫', '과정', '후보', '램', '모델', '별', '공개', '현지', '사건', '준비', '달리', '효과', '단계', '으로써', '상대', 'B', '찾', '2002', '최고', '내놓', '여부', '23', '당시', '관하', '공격', '조', '환경', '무선', '평균', '서', '상용', '가입자', '또한', '22', '제휴', '사이트', '이유', '주가', '급', '각종', '확산', '국제', '이전', '회담', '지원하', '부품', '외국인', '처리', '각', '회의', '영화', '덧붙이', '대회', '26', '영업', '합의', '웹', '영향', '정통부', '활동', '비용', '내리', '월드컵', '아시아', '대학', '전국', '줄이', '27', '의견', '핵심', '호', '잡', '해결', '역시', '빠르', '거치', '28', '없이', '차원', '이런', '행사', '설치', '남', '러시아', '치', '상승', '선수', '얻', '경쟁력', '보유', '활성화', '늘리', '민주당', '바', '경', '주력', '강', '부시', '오후', '넘', '이다', '만나', '2003', '최종', '확정', '연구', '줄', '비중', '29', '전환', '표준', 'DMB', '브랜드', '수사', '마치', '대응', 'KTF', '노력', '메모리', '채택', '부담', '전문', 'ㄴ데', '독일', '신규', '우선', '모듈', '중요', 'PDA', '어도', '관계', '비즈니스', '조치', '작년', '업무', '동시', '대기업', '력', '관련업계', '대만', '오전', 'SW', '기관', '참석', '음', '는다', '핵', '모니터', '으면', '중소기업', '테러', '대로', '영국', '감소', '외국', '인증', '60', 'A', '제기', '개인', '펼치', '초고속', '맞추', '전문업체', 'ㄴ다면서', '개최', '다음', '보고서', '형태', '현', '하락', '거래', '비롯', '달성', '자사', '변화', '돈', '소비자', '2001', '잇따르', '인수', '협의', '상품', '소재', '달하', '무현', '아이', '인식', ' ...

# %%
# check the word embedding result
word = '버스'
print(model.wv[word])
print('size of vector: ', len(model.wv[word]))
# Out:
# [-1.035671    0.47437614  0.17578264  0.21114135  0.28532004 -0.21645187
#  -0.11969339 -0.25866488  0.05896854 -0.04923951  0.3597209   0.38133186
#  -0.00812934  0.21491832  0.14384598 -0.01674394 -0.11356556 -0.14080124
#  -0.02060484 -0.08545088 -0.16076039 -0.21722218 -0.10472752 -0.27132094
#   0.33943757 -0.46941307 -0.31572875  0.42769772 -0.12540789 -0.15096343
#  -0.04650512 -0.06047432 -0.19878888  0.5069182   0.10734709 -0.13395289
#  -0.00288289 -0.18555228  0.05162125  0.38320273  0.28170422  0.13233086
#   0.13138261 -0.2352454   0.3651275  -0.01976934 -0.25788006 -0.01114927
#   0.24317372 -0.16166775  0.36819476  0.35691395  0.11084783  0.39397803
#   0.18633391  0.31877163 -0.10156225  0.2019092   0.01135934  0.16301599
#   0.08479711  0.00684411 -0.17012142  0.1333794  -0.12080101  0.18379413
#   0.05114222 -0.10004972 -0.66074413 -0.04568807 -0.1504878  -0.00674057
#  -0.09479905  0.04554502  0.16238856  0.4021653  -0.5235755  -0.24702998
#  -0.08035028 -0.13925883  0.17153572 -0.13866934  0.18575406  0.2629047
#  -0.37669036 -0.1298319  -0.31267676  0.39472166  0.28899938  0.12878266
#   0.27216247  0.22766967 -0.2819519  -0.19355355  0.07008707  0.23586608
#  -0.1656726  -0.25275168 -0.19075006  0.38395122  0.5050702  -0.02889096
#   0.03627815 -0.20366545  0.5710593   0.17100643 -0.0619728  -0.16228598
#  -0.13946435  0.30695727 -0.34890112 -0.18643112  0.44409332 -0.07746679
#   0.30625463 -0.06856397 -0.17626858  0.22171384  0.02256618  0.02480382
#  -0.04215666 -0.6339832  -0.00131883 -0.6953227  -0.09628949  0.2965199
#   0.12317535 -0.07638341  0.0618064  -0.34169632  0.34343702  0.37742415
#   0.27454117 -0.02341549  0.1713707   0.6689129   0.56362766 -0.2938567
#  -0.39175567 -0.0878621   0.04600676 -0.0651198   0.02344966  0.31572074
#  -0.12615244  0.09081989 -0.13329384  0.26666278  0.05432603 -0.5501033
#  -0.10030378 -0.1791011  -0.3817993  -0.6562619   0.30507386  0.19434382
#   0.19277443  0.12591055 -0.17038724  0.30510375 -0.15637104  0.21743637
#   0.02058064  0.29920042  0.09660041  0.08397322  0.18649288 -0.42071763
#   0.34953883  0.12050253  0.19698076 -0.2772361  -0.15236205  0.21578039
#  -0.15875305  0.12983674 -0.16707009 -0.1803809   0.12392793  0.36490667
#  -0.13576786  0.2225466  -0.21324648 -0.17888466  0.02085597  0.07035112
#   0.08276772  0.00719037 -0.07273879 -0.20071398  0.46656933 -0.3760084
#   0.21882875 -0.1903037   0.40573508  0.0309203   0.12230909 -0.5007776
#  -0.37778068  0.17729993  0.33282277 -0.25117782 -0.00217719  0.39617255
#   0.04164137  0.24406374 -0.3838337   0.01303757  0.23792744 -0.17875834
#  -0.19671504 -0.5697544   0.08772655 -0.39270723  0.4776469  -0.17210901
#  -0.25446028 -0.42533284  0.04065945  0.05595826 -0.0093126   0.48828015
#   0.03948564  0.6166809   0.08670908  0.15718023 -0.00265063  0.07360098
#   0.31927297  0.3075814  -0.20640516 -0.31456926 -0.10783126 -0.02481273
#  -0.27576387  0.19106057  0.2767069   0.23858373  0.05741495 -0.13202679
#   0.2966758  -0.28734362  0.19732179 -0.11988185  0.14636253 -0.2573776
#  -0.0335712  -0.33634084  0.16801544  0.12545562  0.24839506  0.26785067
#   0.10281512  0.09246171 -0.05067046 -0.21736865  0.41233397 -0.14353178
#  -0.05526986 -0.27626878 -0.07798891 -0.02243271 -0.33159494 -0.5614135
#  -0.15598203  0.09136948  0.12345876 -0.15830566 -0.23907451 -0.01153416
#   0.00223855  0.54044974  0.3153519   0.04819596 -0.20085637  0.28671882
#   0.32574603  0.5063375  -0.05621594  0.2077435   0.2073531   0.5033491
#  -0.06570413 -0.10529004 -0.11195908 -0.13148923 -0.14103197  0.3358386
#   0.25508976  0.2962735   0.29821646  0.01156585  0.42199346  0.03458529
#  -0.04533183  0.24219547  0.09640599  0.2657141   0.1671348  -0.15773195]
# size of vector:  300

# %% [markdown]
# # Step 4
# 두 단어 간 유사도 출력하기

# %%
#word1 = '한국'
#word2 = '북한'
print ("Caculate the similarity between word1 and word2")
word1 = input("word1: ")
word2 = input("word2: ")

# check the words are in the vocabulary
no_problem = True
# vocab = model.wv.vocab.keys() # 3.8.0
vocab = model.wv.key_to_index # 4.0.1

if word1 not in vocab:
    print ('The word ' + word1 + ' is not in the vocabulary')
    no_problem = False

if word2 not in vocab:
    print ('The word ' + word2 + ' is not in the vocabulary')
    no_problem = False

if no_problem:
    similarity = model.wv.similarity(word1, word2) # 두 벡터 간의 내적에 기반한 cos유사도 등으로 계산
    print ('The similarity between ' + word1 + ' and ' + word2 + ' : ', similarity)
# Out:
# Caculate the similarity between word1 and word2
# word1: 한국
# word2: 북한
# The similarity between 한국 and 북한 :  0.29495502

# %% [markdown]
# # Step 5
# 주어진 단어들 중 그 평균값에서 가장 먼 한 단어 출력하기

# %%
#words = '소프트웨어 네트워크 프로그램 가방'
print("Find one mismatched word among the given words")
text = input("Text(Words): ")
words = list(text.split())

# check the words are in the vocabulary
no_problem = True
# vocab = model.wv.vocab.keys() # 3.8.0
vocab = model.wv.key_to_index # 4.0.1

for word in words:
    if word not in vocab:
        print('The word ' + word + ' is not in the vocabulary')
        no_problem = False
        break;

if no_problem:
    mismatched = model.wv.doesnt_match(words) # 내적에 기반하여 계산
    print ('the mismatch word among ' + text +' is', mismatched)
# Out:
# Find one mismatched word among the given words
# Text(Words): 아버지 어머니 형 누나 한국
# the mismatch word among 아버지 어머니 형 누나 한국 is 형

# %% [markdown]
# # Step 6
# 어떤 단어들과 가장 가까운, 그러면서 동시에 다른 어떤 단어들로부터는 멀리 떨어진 단어 N개 출력하기

# %%
print("Find the top-N words that are most similar to the given ‘positive’ words and are most different from the given ‘negative’ words")
word = input("Word: ")

no_problem = True
# vocab = model.wv.vocab.keys() # 3.8.0
vocab = model.wv.key_to_index # 4.0.1

if word not in vocab:
    print ('The word ' + word + ' is not in the vocabulary')
    no_problem = False

if no_problem:
    print(model.wv.most_similar(positive=[word]))
# Out:
# Find the top-N words that are most similar to the given ‘positive’ words and are most different from the given ‘negative’ words
# Word: 한국
# [('우리나라', 0.5445699095726013), ('BMC', 0.49306520819664), ('SGI', 0.49253514409065247), ('국내', 0.48649993538856506), ('KPCA', 0.480002760887146), ('휴렛팩커드', 0.4716898202896118), ('정영수', 0.4686005413532257), ('ICA', 0.4683288037776947), ('KISTI', 0.46359169483184814), ('IBM', 0.45915600657463074)]

# %%
#word_a = '한국'
#word_b = '아시아'
#word_c = '유럽'
print('Find the top-N words that are most similar to the given ‘positive’ words and are most different from the given ‘negative’ words w.r.t the result of [ a - b + c ]')
word_a = input("a: ")
word_b = input("b: ")
word_c = input("c: ")

# check the words are in the vocabulary
no_problem = True
# vocab = model.wv.vocab.keys() # 3.8.0
vocab = model.wv.key_to_index # 4.0.1

if word_a not in vocab:
    print ('the word ' + word_a + ' is not in the vocabulary')
    no_problem = False

if word_b not in vocab:
    print ('the word ' + word_b + ' is not in the vocabulary')
    no_problem = False

if word_c not in vocab:
    print ('the word ' + word_c + ' is not in the vocabulary')
    no_problem = False

if no_problem:
    mostsimilar = model.wv.most_similar(positive=[word_a, word_c], negative=[word_b], topn=5)
    print ('most similar word of ' + word_a + ' - ' + word_b + ' + ' + word_c + ' is', mostsimilar[0][0], mostsimilar[1][0], mostsimilar[2][0])
# Out:
# Find the top-N words that are most similar to the given ‘positive’ words and are most different from the given ‘negative’ words w.r.t the result of [ a - b + c ]
# a: 한국
# b: 아시아
# c: 유럽
# most similar word of 한국 - 아시아 + 유럽 is 유럽시장 국내 우리나라
