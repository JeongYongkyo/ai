# %%
import time
start_time = time.time()

def Bridge(n):
    if n == 1: return 1
    else:
        f[0]=1; f[1]=2; f[2]=4
        m = 1904101441
        for i in range(3,n+1):
            f[i] = f[i-1]%m+f[i-2]%m+f[i-3]%m
    return f[n-1]%m
        
#T = int(input())
T=1
for _ in range(T):
    #n = int(input())
    n = 1000000
    f = [0]*(n+1)
    print(Bridge(n))
    
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# 176371517
# --- 0.6900930404663086 seconds ---

# %%
# 조교님
import time
start_time = time.time()

#t = int(input())
t = 1
for _ in range(t):
    #N = int(input())
    N = 1000000
    T = [0]*(N+1)
    for i in range(1,N+1):
        if i == 1:
            T[1] = 1
        elif i == 2:
            T[2] = 2
        elif i == 3:
            T[3] = 4
        else:
            T[i] = (T[i-1]+T[i-2]+T[i-3])%1904101441
    print(T[N])

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# 176371517
# --- 0.5755422115325928 seconds ---

# %%
import time
start_time = time.time()

def Bridge(n):
    if n == 1: return 1
    else:
        f=[1,2,4]
        m = 1904101441
        for i in range(3,n+1):
            f.append(f[i-1]+f[i-2]+f[i-3])
    return f[n-1]%m
        
#T = int(input())
T=1
for _ in range(T):
    #n = int(input())
    n = 1000000
    f = [0]*(n+1)
    print(Bridge(n))
    
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# 176371517
# --- 44.926453828811646 seconds ---
