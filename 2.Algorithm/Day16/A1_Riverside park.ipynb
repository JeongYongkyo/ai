# %%
#T = int(input())
T = 1
for _ in range(T):
    #n = list(map(int,input().split()))
    height = [5, 6, 1, 2, 1, 2, 1, 2]
    #height = [5, 3, 2, 4, 6]
    
    height.insert(0, 0)
    height += [0]
    checked = [0]
    area = 0
    print("height :",height)
    
    for i in range(1, len(height)):
        print("step :",checked)
        print("▶height[checked[-1]] :",height[checked[-1]],", ▶height[i] :",height[i])
        while(checked and (height[checked[-1]] > height[i])):
            print("checked :",checked)
            cur_height = checked.pop()
            #print("▶cur_height :",cur_height)
            print("▶i - 1 - checked[-1] :",i - 1 - checked[-1],", ▶height[cur_height] :",height[cur_height])
            area = max(area, (i - 1 - checked[-1]) * height[cur_height])
            print("area :",area)
            print("-----------------------------------------")
        checked.append(i)
    print(area)
# Out:
# height : [0, 5, 6, 1, 2, 1, 2, 1, 2, 0]
# step : [0]
# ▶height[checked[-1]] : 0 , ▶height[i] : 5
# step : [0, 1]
# ▶height[checked[-1]] : 5 , ▶height[i] : 6
# step : [0, 1, 2]
# ▶height[checked[-1]] : 6 , ▶height[i] : 1
# checked : [0, 1, 2]
# ▶i - 1 - checked[-1] : 1 , ▶height[cur_height] : 6
# area : 6
# -----------------------------------------
# checked : [0, 1]
# ▶i - 1 - checked[-1] : 2 , ▶height[cur_height] : 5
# area : 10
# -----------------------------------------
# step : [0, 3]
# ▶height[checked[-1]] : 1 , ▶height[i] : 2
# step : [0, 3, 4]
# ▶height[checked[-1]] : 2 , ▶height[i] : 1
# checked : [0, 3, 4]
# ▶i - 1 - checked[-1] : 1 , ▶height[cur_height] : 2
# area : 10
# -----------------------------------------
# step : [0, 3, 5]
# ▶height[checked[-1]] : 1 , ▶height[i] : 2
# step : [0, 3, 5, 6]
# ▶height[checked[-1]] : 2 , ▶height[i] : 1
# checked : [0, 3, 5, 6]
# ▶i - 1 - checked[-1] : 1 , ▶height[cur_height] : 2
# area : 10
# -----------------------------------------
# step : [0, 3, 5, 7]
# ▶height[checked[-1]] : 1 , ▶height[i] : 2
# step : [0, 3, 5, 7, 8]
# ▶height[checked[-1]] : 2 , ▶height[i] : 0
# checked : [0, 3, 5, 7, 8]
# ▶i - 1 - checked[-1] : 1 , ▶height[cur_height] : 2
# area : 10
# -----------------------------------------
# checked : [0, 3, 5, 7]
# ▶i - 1 - checked[-1] : 3 , ▶height[cur_height] : 1
# area : 10
# -----------------------------------------
# checked : [0, 3, 5]
# ▶i - 1 - checked[-1] : 5 , ▶height[cur_height] : 1
# area : 10
# -----------------------------------------
# checked : [0, 3]
# ▶i - 1 - checked[-1] : 8 , ▶height[cur_height] : 1
# area : 10
# -----------------------------------------
# 10

# %%
while True:
    n, *heights = list(map(int, input().split()))
    if(n == 0):
        break
    print("n:",n)
    print("heights :",heights)
    # 첫 시점의 계산을 위해 0을 맨 앞에 추가하고,
    heights.insert(0, 0)
    # 마지막 사각형 계산을 위해 0을 끝에 추가합니다.
    heights += [0]
    checked = [0]
    area = 0
    print("heights :",heights)
    # 현재 높이보다 이전 높이가 높으면, while에 진입합니다.
    # 현재 높이가 더 낮은 경우, 넓이를 이어서 계산할 수 없으므로
    # 이전 시점까지 저장됬던 사각형의 높이를 계산합니다.
    # 끝 사각형도 고려해야 하므로, n+1까지 반복합니다.
    for i in range(1, n + 2):
        print("checked :",checked)
        # heights[checked[-1]]은 이전 시점의 사각형 높이
        # heights[i]는 현재 시점의 사각형 높이
        # heights[checked[-1]] > heights[i]는 현재 높이보다 이전 높이가 높은지 확인
        while(checked and (heights[checked[-1]] > heights[i])):
            # 비교할 사각형 index
            cur_height = checked.pop()
            # (i - 1 - checked[-1])은 cur_height와 현재 시점 사이에 몇 개의 사각형이 존재하는지를 판단
            area = max(area, (i - 1 - checked[-1]) * heights[cur_height])
        checked.append(i)
    print(area)
# Out:
# 8 5 6 1 2 1 2 1 2 0
# n: 8
# heights : [5, 6, 1, 2, 1, 2, 1, 2, 0]
# heights : [0, 5, 6, 1, 2, 1, 2, 1, 2, 0, 0]
# checked : [0]
# checked : [0, 1]
# checked : [0, 1, 2]
# checked : [0, 3]
# checked : [0, 3, 4]
# checked : [0, 3, 5]
# checked : [0, 3, 5, 6]
# checked : [0, 3, 5, 7]
# checked : [0, 3, 5, 7, 8]
# 10
# 0
