# %%
# 조교님 - import bisect
import bisect

def find(l,x):
    i = bisect.bisect_left(l,x)
    if i == 0: return l[0]
    if i >= len(l): return l[-1]
    if l[i]-x < x-l[i-1]: return l[i]
    else : return l[i-1]
    
t = int(input())
for _ in range(t):
    l = list(map(int,input().split()))
    q = list(map(int,input().split()))
    ans=[binary(l,0,len(l),x) for x in q]
    print(*ans)
