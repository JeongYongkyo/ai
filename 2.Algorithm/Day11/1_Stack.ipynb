# %%
t = int(input())

for _ in range(t):
    L = []
    n = int(input())
    for _ in range(n):
        m = int(input())
        if m > 0:
            L.append(m)
        else:
            print(L[-1])
            L.pop(-1)
# Out:
# 2
# 10
# 1
# -1
# 1
# 2
# 7
# 3
# -1
# 3
# 4
# -1
# 4
# 5
# -1
# 5
# 6
# 3
# 4
# 2
# 1
# 5
# -1
# 5

# %%
t = int(input())

for _ in range(t):
    n = int(input())
    s=[]
    for _ in range(n):
        q=int(input())
        if q == -1:
            print(s.pop())
        else:
            s.append(q)
