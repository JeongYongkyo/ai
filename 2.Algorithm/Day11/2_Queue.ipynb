# %%
import collections

t = int(input())

for _ in range(t):
    queue=collections.deque([])
    n = int(input())
    for _ in range(n):
        m = int(input())
        if m > 0:
            queue.append(m)
        else:
            print(queue[0])
            queue.popleft()
# Out:
# 2
# 10
# 1
# -1
# 1
# 2
# 7
# 3
# -1
# 2
# 4
# -1
# 7
# 5
# -1
# 3
# 6
# 3
# 4
# 2
# 1
# 5
# -1
# 3

# %%
t = int(input())

for _ in range(t):
    n = int(input())
    queue = []
    head = 0
    tail = 0
    for i in range(n):
        if q == -1:
            print(queue[head])
            head += 1
        else:
            queue.append(q)
            tail += 1

# %%
from collections import deque

t = int(input())

for _ in range(t):
    n = int(input())
    deq = deque([])
    for _ in range(n):
        q = int(input())
        if q == -1:
            print(deq.popleft())
        else:
            deq.append(q)
