# %%
def slope(location):
    location.sort(key = lambda x : x[0])
    tmp = 0
    for i in range(N-1):
        Max = abs((location[i][1]-location[i+1][1])/(location[i][0]-location[i+1][0]))
        if Max > tmp: 
            tmp = Max
            x1 = location[i][0]
            x2 = location[i][1]
            y1 = location[i+1][0]
            y2 = location[i+1][1]
    return(x1,x2,y1,y2)
    
t = int(input())
for _ in range(t):
    N = int(input())
    location = []
    for _ in range(N):
        a = tuple(map(int,input().split()))
        location.append(a)
    ans = slope(location)
    print(*ans)
    location = []
# Out:
# 2
# 7
# 2 7
# 12 4
# 4 5
# 10 7
# 6 2
# 9 1
# 8 8
# 8 8 9 1
# 4
# 1 1
# 2 2
# 5 5
# 6 6
# 1 1 2 2
