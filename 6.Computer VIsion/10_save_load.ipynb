# %% [markdown]
# # Saving & Loading Deep Network
# * Saving
#
#     `torch.save(net.state_dict(), './ckpt/net.ckpt')`
#
# * Loading
#
#     `net.load_state_dict(torch.load('./ckpt/net.ckpt'))`
#
# #### Exmaple

# %%
import torch
import torch.nn as nn

from pathlib import Path

# %%
##########
# TRAINING
##########

# assume class Net(nn.Module) is pre-defined
net = Net().to(torch.device('cuda'))

# training loop
# ...
# end

# save the network's weights
Path('./ckpt').mkdir(exist_ok=True)
torch.save(net.state_dict(), './ckpt/net.ckpt')

# %%
##########
# TESTING
##########

# assume class Net(nn.Module) is pre-defined
net = Net().to(torch.device('cuda'))

# load network weights
net.load_state_dict(torch.load('./ckpt/net.ckpt'))

# testing loop
# ...
# end
