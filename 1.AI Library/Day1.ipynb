# %% [markdown]
# ### print() 사용
# print()를 사용하여 Hello world!! 출력

# %%
print("Hello world!!")
# Out:
# Hello world!!

# %% [markdown]
# ### 주석처리
# 해당 줄을 드래그 한 후 Ctrl+L

# %%
# print("Hello world!!")
print("Hello world!!")
print("Hello world!!")
# print("Hello world!!")
# Out:
# Hello world!!
# Hello world!!

# %% [markdown]
# ### 사칙연산

# %%
7 % 3
# Out:
# 1

# %%
print(7%3)
# Out:
# 1

# %%
3 * 5 ** 2
# Out:
# 75

# %%
10 / 10
# Out:
# 1.0

# %%
a = 1

# %%
type(a)
# Out:
# int

# %%
print(a)
# Out:
# 1

# %%
a = a + 1

# %%
name = input("Enter your name : ")
print(name)
# Out:
# Enter your name : Hong Gildong
# Hong Gildong

# %%
type(name)

# %% [markdown]
# ### 들여쓰기, 내어쓰기
# TAB, SHIFT + TAB

# %% [markdown]
# ### 라인 번호
# 대문자L or 소문자L

# %% [markdown]
# ***test***
# **test**
# *test*
